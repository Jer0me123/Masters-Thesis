# %% [markdown]
# # Environment Setup
#
# This notebook contains the necessary installs required to run the scripts

# %%
# pip install torch torchvision --index-url https://download.pytorch.org/whl/cu124

# %%
# pip install -U scikit-learn

# %%
# pip install tqdm
