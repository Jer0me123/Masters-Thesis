# %% [markdown]
# # `clip_retrieval.clip_client`
#
# This python module allows you to query a backend remote via its exposed REST api.

# %% [markdown]
# ## Install

# %%
# %pip install clip-retrieval img2dataset
# Out:
# Requirement already satisfied: clip-retrieval in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (2.44.0)
# Requirement already satisfied: img2dataset in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (1.45.0)
# Requirement already satisfied: clip-anytorch<3,>=2.5.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (2.6.0)
# Requirement already satisfied: tqdm<5,>=4.62.3 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (4.66.5)
# Requirement already satisfied: fire<0.6.0,>=0.4.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (0.5.0)
# Requirement already satisfied: torch<3,>=1.7.1 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (2.4.1+cu124)
# Requirement already satisfied: torchvision<2,>=0.10.1 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (0.19.1)
# Requirement already satisfied: numpy<2,>=1.19.5 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (1.26.4)
# Requirement already satisfied: faiss-cpu<2,>=1.7.2 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (1.9.0)
# Requirement already satisfied: flask<4,>=3.0.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (3.0.3)
# Requirement already satisfied: flask-restful<1,>=0.3.9 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (0.3.10)
# Requirement already satisfied: flask-cors<5,>=4.0.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (4.0.2)
# Requirement already satisfied: pandas<3,>=1.1.5 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (2.2.3)
# Requirement already satisfied: pyarrow<15,>=6.0.1 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (14.0.2)
# Requirement already satisfied: autofaiss<3,>=2.9.6 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (2.17.0)
# Requirement already satisfied: webdataset<0.3,>=0.2 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (0.2.100)
# Requirement already satisfied: h5py<4,>=3.1.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (3.12.1)
# Requirement already satisfied: prometheus-client<1,>=0.13.1 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (0.21.0)
# Requirement already satisfied: fsspec in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (2024.6.1)
# Requirement already satisfied: sentence-transformers<3,>=2.2.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (2.7.0)
# Requirement already satisfied: wandb<0.17,>=0.12.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (0.16.6)
# Requirement already satisfied: open-clip-torch<3.0.0,>=2.0.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (2.26.1)
# Requirement already satisfied: requests<3,>=2.27.1 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (2.32.3)
# Requirement already satisfied: aiohttp<4,>=3.8.1 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (3.10.10)
# Requirement already satisfied: multilingual-clip<2,>=1.0.10 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (1.0.10)
# Requirement already satisfied: transformers in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (4.45.2)
# Requirement already satisfied: urllib3<2 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (1.26.20)
# Requirement already satisfied: scipy<1.12 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (1.11.4)
# Requirement already satisfied: all-clip<2 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-retrieval) (1.2.0)
# Requirement already satisfied: opencv-python-headless<5,>=4.5.5.62 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from img2dataset) (4.10.0.84)
# Requirement already satisfied: exifread-nocycle<4,>=3.0.1 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from img2dataset) (3.0.1)
# Requirement already satisfied: albumentations<2,>=1.1.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from img2dataset) (1.4.18)
# Requirement already satisfied: dataclasses<1.0.0,>=0.6 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from img2dataset) (0.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from aiohttp<4,>=3.8.1->clip-retrieval) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from aiohttp<4,>=3.8.1->clip-retrieval) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from aiohttp<4,>=3.8.1->clip-retrieval) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from aiohttp<4,>=3.8.1->clip-retrieval) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from aiohttp<4,>=3.8.1->clip-retrieval) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from aiohttp<4,>=3.8.1->clip-retrieval) (1.15.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from aiohttp<4,>=3.8.1->clip-retrieval) (4.0.3)
# Requirement already satisfied: scikit-image>=0.21.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from albumentations<2,>=1.1.0->img2dataset) (0.24.0)
# Requirement already satisfied: PyYAML in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from albumentations<2,>=1.1.0->img2dataset) (6.0.2)
# Requirement already satisfied: pydantic>=2.7.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from albumentations<2,>=1.1.0->img2dataset) (2.9.2)
# Requirement already satisfied: albucore==0.0.17 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from albumentations<2,>=1.1.0->img2dataset) (0.0.17)
# Requirement already satisfied: eval-type-backport in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from albumentations<2,>=1.1.0->img2dataset) (0.2.0)
# Requirement already satisfied: embedding-reader<2,>=1.5.1 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from autofaiss<3,>=2.9.6->clip-retrieval) (1.7.0)
# Requirement already satisfied: ftfy in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-anytorch<3,>=2.5.0->clip-retrieval) (6.3.0)
# Requirement already satisfied: regex in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from clip-anytorch<3,>=2.5.0->clip-retrieval) (2024.9.11)
# Requirement already satisfied: packaging in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from faiss-cpu<2,>=1.7.2->clip-retrieval) (24.1)
# Requirement already satisfied: six in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from fire<0.6.0,>=0.4.0->clip-retrieval) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from fire<0.6.0,>=0.4.0->clip-retrieval) (2.5.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from flask<4,>=3.0.0->clip-retrieval) (3.0.4)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from flask<4,>=3.0.0->clip-retrieval) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from flask<4,>=3.0.0->clip-retrieval) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from flask<4,>=3.0.0->clip-retrieval) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from flask<4,>=3.0.0->clip-retrieval) (1.8.2)
# Requirement already satisfied: aniso8601>=0.82 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from flask-restful<1,>=0.3.9->clip-retrieval) (9.0.1)
# Requirement already satisfied: pytz in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from flask-restful<1,>=0.3.9->clip-retrieval) (2024.2)
# Requirement already satisfied: huggingface-hub in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from open-clip-torch<3.0.0,>=2.0.0->clip-retrieval) (0.25.2)
# Requirement already satisfied: timm in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from open-clip-torch<3.0.0,>=2.0.0->clip-retrieval) (1.0.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from pandas<3,>=1.1.5->clip-retrieval) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from pandas<3,>=1.1.5->clip-retrieval) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from requests<3,>=2.27.1->clip-retrieval) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from requests<3,>=2.27.1->clip-retrieval) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from requests<3,>=2.27.1->clip-retrieval) (2024.8.30)
# Requirement already satisfied: scikit-learn in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from sentence-transformers<3,>=2.2.0->clip-retrieval) (1.5.2)
# Requirement already satisfied: Pillow in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from sentence-transformers<3,>=2.2.0->clip-retrieval) (10.4.0)
# Requirement already satisfied: filelock in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from torch<3,>=1.7.1->clip-retrieval) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from torch<3,>=1.7.1->clip-retrieval) (4.12.2)
# Requirement already satisfied: sympy in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from torch<3,>=1.7.1->clip-retrieval) (1.13.3)
# Requirement already satisfied: networkx in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from torch<3,>=1.7.1->clip-retrieval) (3.4.1)
# Requirement already satisfied: colorama in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from tqdm<5,>=4.62.3->clip-retrieval) (0.4.6)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from transformers->clip-retrieval) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from transformers->clip-retrieval) (0.20.1)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from wandb<0.17,>=0.12.0->clip-retrieval) (3.1.43)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from wandb<0.17,>=0.12.0->clip-retrieval) (6.0.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from wandb<0.17,>=0.12.0->clip-retrieval) (2.16.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from wandb<0.17,>=0.12.0->clip-retrieval) (0.4.0)
# Requirement already satisfied: setproctitle in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from wandb<0.17,>=0.12.0->clip-retrieval) (1.3.3)
# Requirement already satisfied: setuptools in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from wandb<0.17,>=0.12.0->clip-retrieval) (75.1.0)
# Requirement already satisfied: appdirs>=1.4.3 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from wandb<0.17,>=0.12.0->clip-retrieval) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from wandb<0.17,>=0.12.0->clip-retrieval) (4.25.5)
# Requirement already satisfied: braceexpand in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from webdataset<0.3,>=0.2->clip-retrieval) (0.1.7)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from GitPython!=3.1.29,>=1.0.0->wandb<0.17,>=0.12.0->clip-retrieval) (4.0.11)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from Jinja2>=3.1.2->flask<4,>=3.0.0->clip-retrieval) (3.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from pydantic>=2.7.0->albumentations<2,>=1.1.0->img2dataset) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from pydantic>=2.7.0->albumentations<2,>=1.1.0->img2dataset) (2.23.4)
# Requirement already satisfied: imageio>=2.33 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from scikit-image>=0.21.0->albumentations<2,>=1.1.0->img2dataset) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from scikit-image>=0.21.0->albumentations<2,>=1.1.0->img2dataset) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from scikit-image>=0.21.0->albumentations<2,>=1.1.0->img2dataset) (0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4,>=3.8.1->clip-retrieval) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from ftfy->clip-anytorch<3,>=2.5.0->clip-retrieval) (0.2.13)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from scikit-learn->sentence-transformers<3,>=2.2.0->clip-retrieval) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from scikit-learn->sentence-transformers<3,>=2.2.0->clip-retrieval) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from sympy->torch<3,>=1.7.1->clip-retrieval) (1.3.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\user\onedrive\desktop\masters units\research topics in ai\laion-5b testing\.venv\lib\site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb<0.17,>=0.12.0->clip-retrieval) (5.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Setup

# %%
from IPython.display import Image, display
from clip_retrieval.clip_client import ClipClient, Modality

IMAGE_BASE_URL = "https://github.com/rom1504/clip-retrieval/raw/main/tests/test_clip_inference/test_images/"

def log_result(result):
    id, caption, url, similarity = result["id"], result["caption"], result["url"], result["similarity"]
    print(f"id: {id}")
    print(f"caption: {caption}")
    print(f"url: {url}")
    print(f"similarity: {similarity}")
    display(Image(url=url, unconfined=True))

client = ClipClient(
    url="https://knn.laion.ai/knn-service",
    indice_name="laion5B-L-14",
    aesthetic_score=9,
    aesthetic_weight=0.5,
    modality=Modality.IMAGE,
    num_images=10,
)

# %% [markdown]
# ## Query by text

# %%
cat_results = client.query(text="an image of a cat")
log_result(cat_results[0])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\User\OneDrive\Desktop\Masters Units\Research Topics in AI\LAION-5B Testing\.venv\lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 cat_results = client.query(text="an image of a cat")
#       2 log_result(cat_results[0])
#
# File c:\Users\User\OneDrive\Desktop\Masters Units\Research Topics in AI\LAION-5B Testing\.venv\lib\site-packages\clip_retrieval\clip_client.py:84, in ClipClient.query(self, text, image, embedding_input)
#      82     raise ValueError("Only one of text or image can be provided.")
#      83 if text:
# ---> 84     return self.__search_knn_api__(text=text)
#      85 elif image:
#      86     if image.startswith("http"):
#
# File c:\Users\User\OneDrive\Desktop\Masters Units\Research Topics in AI\LAION-5B Testing\.venv\lib\site-packages\clip_retrieval\clip_client.py:153, in ClipClient.__search_knn_api__(self, text, image, image_url, embedding_input)
#     129         encoded_string = base64.b64encode(image_file.read())
#     130         image = str(encoded_string.decode("utf-8"))
#     131 return requests.post(
#     132     self.url,
#     133     data=json.dumps(
#     134         {
#     135             "text": text,
#     136             "image": image,
#     137             "image_url": image_url,
#     138             "embedding_input": embedding_input,
#     139             "deduplicate": self.deduplicate,
#     140             "use_safety_model": self.use_safety_model,
#     141             "use_violence_detector": self.use_violence_detector,
#     142             "indice_name": self.indice_name,
#     143             "use_mclip": self.use_mclip,
#     144             "aesthetic_score": self.aesthetic_score,
#     145             "aesthetic_weight": self.aesthetic_weight,
#     146             "modality": self.modality,
#     147             "num_images": self.num_images,
#     148             # num_results_ids is hardcoded to the num_images parameter.
#     149             "num_result_ids": self.num_images,
#     150         }
#     151     ),
#     152     timeout=3600,
# --> 153 ).json()
#
# File c:\Users\User\OneDrive\Desktop\Masters Units\Research Topics in AI\LAION-5B Testing\.venv\lib\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## Query by image

# %%
beach_results = client.query(image="https://github.com/rom1504/clip-retrieval/raw/main/tests/test_clip_inference/test_images/321_421.jpg")
log_result(beach_results[0])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\User\OneDrive\Desktop\Masters Units\Research Topics in AI\LAION-5B Testing\.venv\lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 beach_results = client.query(image="https://github.com/rom1504/clip-retrieval/raw/main/tests/test_clip_inference/test_images/321_421.jpg")
#       2 log_result(beach_results[0])
#
# File c:\Users\User\OneDrive\Desktop\Masters Units\Research Topics in AI\LAION-5B Testing\.venv\lib\site-packages\clip_retrieval\clip_client.py:87, in ClipClient.query(self, text, image, embedding_input)
#      85 elif image:
#      86     if image.startswith("http"):
# ---> 87         return self.__search_knn_api__(image_url=image)
#      88     else:
#      89         assert Path(image).exists(), f"{image} does not exist."
#
# File c:\Users\User\OneDrive\Desktop\Masters Units\Research Topics in AI\LAION-5B Testing\.venv\lib\site-packages\clip_retrieval\clip_client.py:153, in ClipClient.__search_knn_api__(self, text, image, image_url, embedding_input)
#     129         encoded_string = base64.b64encode(image_file.read())
#     130         image = str(encoded_string.decode("utf-8"))
#     131 return requests.post(
#     132     self.url,
#     133     data=json.dumps(
#     134         {
#     135             "text": text,
#     136             "image": image,
#     137             "image_url": image_url,
#     138             "embedding_input": embedding_input,
#     139             "deduplicate": self.deduplicate,
#     140             "use_safety_model": self.use_safety_model,
#     141             "use_violence_detector": self.use_violence_detector,
#     142             "indice_name": self.indice_name,
#     143             "use_mclip": self.use_mclip,
#     144             "aesthetic_score": self.aesthetic_score,
#     145             "aesthetic_weight": self.aesthetic_weight,
#     146             "modality": self.modality,
#     147             "num_images": self.num_images,
#     148             # num_results_ids is hardcoded to the num_images parameter.
#     149             "num_result_ids": self.num_images,
#     150         }
#     151     ),
#     152     timeout=3600,
# --> 153 ).json()
#
# File c:\Users\User\OneDrive\Desktop\Masters Units\Research Topics in AI\LAION-5B Testing\.venv\lib\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## Query by embedding

# %%
import clip  # pylint: disable=import-outside-toplevel
import torch

model, preprocess = clip.load("ViT-L/14", device="cpu", jit=True)

import urllib
import io
import numpy as np
def download_image(url):
    urllib_request = urllib.request.Request(
        url,
        data=None,
        headers={"User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:72.0) Gecko/20100101 Firefox/72.0"},
    )
    with urllib.request.urlopen(urllib_request, timeout=10) as r:
        img_stream = io.BytesIO(r.read())
    return img_stream
def normalized(a, axis=-1, order=2):
    l2 = np.atleast_1d(np.linalg.norm(a, order, axis))
    l2[l2 == 0] = 1
    return a / np.expand_dims(l2, axis)

def get_text_emb(text):
    with torch.no_grad():
        text_emb = model.encode_text(clip.tokenize([text], truncate=True).to("cpu"))
        text_emb /= text_emb.norm(dim=-1, keepdim=True)
        text_emb = text_emb.cpu().detach().numpy().astype("float32")[0]
    return text_emb

from PIL import Image as pimage

def get_image_emb(image_url):
    with torch.no_grad():
        image = pimage.open(download_image(image_url))
        image_emb = model.encode_image(preprocess(image).unsqueeze(0).to("cpu"))
        image_emb /= image_emb.norm(dim=-1, keepdim=True)
        image_emb = image_emb.cpu().detach().numpy().astype("float32")[0]
        return image_emb

# %%
red_tshirt_text_emb =  get_text_emb("red tshirt")
red_tshirt_results = client.query(embedding_input=red_tshirt_text_emb.tolist())
log_result(red_tshirt_results[0])
# Out:
# id: 3142652315
# caption: KCTS29 100% Cotton Unisex Kids T Shirt Crew Neck V Neck Solid Maroon
# url: https://cdn.shopify.com/s/files/1/1531/9423/products/CTS29_100_Cotton_T_Shirt_Crew_Neck_V_Neck_Long_Sleeves_Solid_Maroon_27f4c580-c286-4e20-b7d7-110c4b2a3ff3_large.jpg?v=1476875623
# similarity: 0.5375761389732361
# <img src="https://cdn.shopify.com/s/files/1/1531/9423/products/CTS29_100_Cotton_T_Shirt_Crew_Neck_V_Neck_Long_Sleeves_Solid_Maroon_27f4c580-c286-4e20-b7d7-110c4b2a3ff3_large.jpg?v=1476875623" class="unconfined"/>

# %%
blue_dress_image_emb = get_image_emb("https://rukminim1.flixcart.com/image/612/612/kv8fbm80/dress/b/5/n/xs-b165-royal-blue-babiva-fashion-original-imag86psku5pbx2g.jpeg?q=70")
blue_dress_results = client.query(embedding_input=blue_dress_image_emb.tolist())
log_result(blue_dress_results[0])
# Out:
# id: 2463946620
# caption: 8c7889e0b92b Cinderella Divine 1295 Long Chiffon Grecian Royal Blue Dress Mid Length  Sleeves V Neck ...
# url: https://cdn.shopify.com/s/files/1/1417/0920/products/1295cd-royal-blue_cfcbd4bc-ed74-47c0-8659-c1b8691990df.jpg?v=1527650905
# similarity: 0.9430060386657715
# <img src="https://cdn.shopify.com/s/files/1/1417/0920/products/1295cd-royal-blue_cfcbd4bc-ed74-47c0-8659-c1b8691990df.jpg?v=1527650905" class="unconfined"/>

# %%
red_tshirt_text_emb =  get_text_emb("red tshirt")
blue_dress_image_emb = get_image_emb("https://rukminim1.flixcart.com/image/612/612/kv8fbm80/dress/b/5/n/xs-b165-royal-blue-babiva-fashion-original-imag86psku5pbx2g.jpeg?q=70")
mean_emb = normalized(red_tshirt_text_emb + blue_dress_image_emb)[0]
mean_results = client.query(embedding_input=mean_emb.tolist())
log_result(mean_results[0])
# Out:
# id: 2702080924
# caption: CLEARANCE - Long Chiffon Grecian Red Dress Mid Length Sleeves V Neck (Size Medium)
# url: https://cdn-img-3.wanelo.com/p/716/c27/0c0/aef7a32a4317370b6f7f14b/x354-q80.jpg
# similarity: 0.824600338935852
# <img src="https://cdn-img-3.wanelo.com/p/716/c27/0c0/aef7a32a4317370b6f7f14b/x354-q80.jpg" class="unconfined"/>

# %% [markdown]
# ## Download and format a dataset from the results of a query
#
# If you have some images of your own, you can query each one and collect the results into a custom dataset (a small subset of LAION-5B)

# %%
# Create urls from known images in repo
import json
from tqdm import tqdm
test_images = [f"{IMAGE_BASE_URL}{image}" for image in ["123_456.jpg", "208_495.jpg", "321_421.jpg", "389_535.jpg", "416_264.jpg", "456_123.jpg", "524_316.jpg"]]

# Re-initialize client with higher num_images
client = ClipClient(url="https://knn.laion.ai/knn-service", indice_name="laion5B-L-14", num_images=40)

# Run one query per image
combined_results = []
for image in tqdm(test_images):
    combined_results.extend(client.query(image=image))

# Save results to json file
with open("search-results.json", "w") as f:
    json.dump(combined_results, f)
# Out:
# 100%|██████████| 7/7 [00:17<00:00,  2.44s/it]

# %%
# !img2dataset "search-results.json" --input_format="json" --caption_col "caption" --output_folder="laion-enhanced-dataset" --resize_mode="no" --output_format="files"
# Out:
# Starting the downloading of this file
# Sharding file number 1 of 1 called /home/samsepiol/Projects/clip-retrieval/notebook/search-results.json
# 0it [00:00, ?it/s]File sharded in 1 shards
# Downloading starting now, check your bandwidth speed (with bwm-ng)your cpu (with htop), and your disk usage (with iotop)!
# 1it [00:32, 32.08s/it]
# worker  - success: 0.921 - failed to download: 0.079 - failed to resize: 0.000 - images per sec: 2 - count: 76
# total   - success: 0.921 - failed to download: 0.079 - failed to resize: 0.000 - images per sec: 2 - count: 76

# %%
import os
print(f"Done! Download/copy the contents of {os.getcwd()}/laion-enhanced-dataset/")
# !realpath laion-enhanced-dataset/
# Out:
# Done! Download/copy the contents of /home/samsepiol/Projects/clip-retrieval/notebook/laion-enhanced-images/
# /home/samsepiol/Projects/clip-retrieval/notebook/laion-enhanced-images/00000.tar
