# %%
# pip install -U pip setuptools wheel

# %%
# pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124

# %%
# pip install "numpy==1.26.4"

# %%
# pip install -U openmim

# %%
# !mim install mmengine "mmcv>=2.0.0rc4,<2.2.0" "mmdet>=3.0.0,<3.3.0" "mmpose>=1.0.0,<1.4.0"

# %%
# pip install opencv-python matplotlib pycocotools xtcocotools tqdm scipy pillow

# %%
# pip install ultralytics

# %%
# pip install xtcocotools pycocotools

# %%
# pip install tensorflow tensorflow-hub

# %%
# pip install mediapipe

# %%
import torch, numpy, mmcv, mmengine, mmdet, mmpose

print("CUDA:", torch.cuda.is_available())
print("NumPy:", numpy.__version__)
print("MMCV:", mmcv.__version__)
print("MMEngine:", mmengine.__version__)
print("MMDet:", mmdet.__version__)
print("MMPose:", mmpose.__version__)
# Out:
# CUDA: True
# NumPy: 2.2.6
# MMCV: 2.1.0
# MMEngine: 0.10.7
# MMDet: 3.2.0
# MMPose: 1.3.2

# %%
import torch
print(torch.cuda.is_available(), torch.__version__)
# Out:
# True 2.1.2+cu118

# %%
import torch, numpy, mmcv, mmdet, mmpose
from mmcv.ops import MultiScaleDeformableAttention
print("Torch:", torch.__version__)
print("NumPy:", numpy.__version__)
print("MMCV:", mmcv.__version__)
print("MMDet:", mmdet.__version__)
print("MMPose:", mmpose.__version__)
print("All imports OK")
# Out:
# Torch: 2.1.2+cu118
# NumPy: 1.23.5
# MMCV: 2.1.0
# MMDet: 3.2.0
# MMPose: 1.3.2
# All imports OK

# %%
import numpy
print(numpy.__version__)
# Out:
# 1.23.5
