# %% [markdown]
# # Environment Setup

# %%
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu124

# %%
# !pip install tqdm

# %%
# !pip install opencv-python

# %%
# !pip install omegaconf

# %%
# !pip install einops

# %%
# !pip install pytorch-lightning

# %%
# !pip install requests

# %%
# !pip install https://huggingface.co/madbuda/triton-windows-builds/resolve/main/triton-3.0.0-cp310-cp310-win_amd64.whl

# %% [markdown]
# # Additional Requirements Setup

# %%
# !mkdir model

# %%
# # Download model.ckpt
# !curl -L -C - -o model/kl-f4.zip https://ommer-lab.com/files/latent-diffusion/kl-f4.zip

# %%
# !tar -xf model/kl-f4.zip -C model
