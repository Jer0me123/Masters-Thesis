# %% [markdown]
# # Environment Setup

# %% [markdown]
# <!-- pip install torch==2.1.2+cu118 torchvision==0.16.2+cu118 --index-url https://download.pytorch.org/whl/cu118 -->
#
# <!-- pip install numpy==1.23.5 -->
#
# <!-- pip install openmim -->
#
# <!-- mim install mmcv==2.1.0 -->
#
# <!-- mim install mmdet==3.2.0 -->
#
# <!-- mim install mmpose==1.3.2 -->
#
# <!-- pip install tensorflow==2.13.1 tensorflow-hub==0.16.1  -->
#
# <!-- pip install --upgrade typing_extensions -->
#
# <!-- pip install mediapipe  -->
#
# <!-- pip install ultralytics -->
#
# <!-- pip install --upgrade typing_extensions -->
#
# <!-- pip install numpy==1.23.5 -->
#
# <!-- pip install PyTurboJPEG -->
#
# <!-- pip install seaborn -->

# %%
import torch
print("Torch:", torch.__version__)

import numpy
print("NumPy:", numpy.__version__)

import mmcv
print("MMCV:", mmcv.__version__)

import mmdet
print("MMDet:", mmdet.__version__)

import mmpose
print("MMPose:", mmpose.__version__)

# from mmcv.ops import MultiScaleDeformableAttention
import tensorflow as tf
print("TensorFlow:", tf.__version__)

import mediapipe as mp
print("MediaPipe:", mp.__version__)

import ultralytics
print("Ultralytics:", ultralytics.__version__)
print("All imports OK")
# Out:
# Torch: 2.1.2+cu118
# NumPy: 1.23.5
# MMCV: 2.1.0
# MMDet: 3.2.0
# MMPose: 1.3.2
# TensorFlow: 2.13.1
# MediaPipe: 0.10.31
# Ultralytics: 8.3.241
# All imports OK

# %% [markdown]
# # Evaluation Dataset Setup

# %%
# !mkdir "EvaluationDatasets/Coco2017"

# %%
# Download COCO 2017 validation images
# !curl -L -C - -o EvaluationDatasets/Coco2017/val2017.zip http://images.cocodataset.org/zips/val2017.zip

# %%
# Unzip EvaluationDatasets/val2017.zip
# !tar -xf EvaluationDatasets/Coco2017/val2017.zip -C EvaluationDatasets/Coco2017

# %%
# Download COCO 2017 annotations
# !curl -L -C - -o EvaluationDatasets/Coco2017/annotations_trainval2017.zip http://images.cocodataset.org/annotations/annotations_trainval2017.zip

# %%
# Unzip EvaluationDatasets/annotations_trainval2017.zip
# !tar -xf EvaluationDatasets/Coco2017/annotations_trainval2017.zip -C EvaluationDatasets/Coco2017
